# %%
#Read Dataset

import pandas as pd
ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
#1 Understand the range of values spread ie 75% 50% and mean std dev

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3330.000000       3333.000000        3333.000000      3330.000000
# mean        100.420721         30.562307         200.980348       100.713213
# ...

# %%
#2 Sort the data with total day minutes, total day calls, total eve minutes, total eve calls

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
df.sort_values(["total day minutes", "total day calls", "total eve minutes", "total eve calls"])
# Out:
#      state  account length  area code phone number international plan  \
# 1345    SD              98        415     392-2555                 no
# 1397    VT             101        510     413-7655                 no
# 2736    OK             127        510     403-1128                 no
# 2753    OH             134        415     406-4158                 no
# 1986    WI              70        415     405-9233                 no
# ...    ...             ...        ...          ...                ...
# 605     MO             112        415     373-2053                 no
# 156     OH              83        415     370-9116                 no
# 2594    OH             115        510     348-1163                yes
# 985     NY              64        415     345-9140                yes
# 365     CO             154        415     343-5709                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
#3 List the data according to total day calls > 100 and < 300

import pandas as pd
ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)

totalcalls=pd.DataFrame(df,columns=["total day minutes", "total day calls","total day charge","total eve minutes",
 "total eve calls", "total eve charge", "total night minutes", "total night calls", "total night charge",])

ds = totalcalls.loc[(totalcalls["total day calls"]>100) & (totalcalls["total day calls"]<300)]
ds
# Out:
#       total day minutes  total day calls  total day charge  total eve minutes  \
# 0                 265.1            110.0             45.07              197.4
# 1                 161.6            123.0             27.47              195.5
# 2                 243.4            114.0             41.38              121.2
# 4                 166.7            113.0             28.34              148.3
# 10                129.1            137.0             21.95              228.5
# ...                 ...              ...               ...                ...
# 3324              169.8            114.0             28.87              197.7
# 3326              106.6            128.0             18.12              284.8
# 3330              180.8            109.0             30.74              288.8
# 3331              213.8            105.0             36.35              159.6
# 3332              234.4            113.0             39.85              265.9
#
# ...

# %%
#4 List the data according to total day calls < 300

import pandas as pd
ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)

totalcalls=pd.DataFrame(df,columns=["total day minutes", "total day calls","total day charge","total eve minutes",
 "total eve calls", "total eve charge", "total night minutes", "total night calls", "total night charge",])

ds=totalcalls.loc[totalcalls["total day calls"]< 300]
ds
# Out:
#       total day minutes  total day calls  total day charge  total eve minutes  \
# 0                 265.1            110.0             45.07              197.4
# 1                 161.6            123.0             27.47              195.5
# 2                 243.4            114.0             41.38              121.2
# 3                 299.4             71.0             50.90               61.9
# 4                 166.7            113.0             28.34              148.3
# ...                 ...              ...               ...                ...
# 3328              156.2             77.0             26.55              215.5
# 3329              231.1             57.0             39.29              153.4
# 3330              180.8            109.0             30.74              288.8
# 3331              213.8            105.0             36.35              159.6
# 3332              234.4            113.0             39.85              265.9
#
# ...

# %%
#4 List the data according to total day calls < 300

totalcalls=pd.DataFrame(df,columns=["total day calls"])

ds=totalcalls.loc[totalcalls["total day calls"]< 300]
ds
# Out:
#       total day calls
# 0               110.0
# 1               123.0
# 2               114.0
# 3                71.0
# 4               113.0
# ...               ...
# 3328             77.0
# 3329             57.0
# 3330            109.0
# 3331            105.0
# 3332            113.0
#
# [3330 rows x 1 columns]

# %%
#5 List the data according to total total night calls  > 100 

totalcalls=pd.DataFrame(df,columns=["total night calls"])
ds=totalcalls.loc[totalcalls["total night calls"]>100]
ds
# Out:
#       total night calls
# 1                 103.0
# 2                 104.0
# 4                 121.0
# 5                 118.0
# 6                 118.0
# ...                 ...
# 3321              134.0
# 3325              109.0
# 3327              128.0
# 3329              123.0
# 3331              137.0
#
# [1654 rows x 1 columns]

# %%
#6 Check if there is any missing values or outliers in the dataset

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           3
# total day charge          0
# total eve minutes         0
# total eve calls           3
# total eve charge          0
# total night minutes       0
# total night calls         5
# total night charge        0
# total intl minutes        0
# total intl calls          5
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
#6 Check if there is any missing values or outliers in the dataset

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
df.isnull().head()
# Out:
#    state  account length  area code  phone number  international plan  \
# 0  False           False      False         False               False
# 1  False           False      False         False               False
# 2  False           False      False         False               False
# 3  False           False      False         False               False
# 4  False           False      False         False               False
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0            False                  False              False            False
# 1            False                  False              False            False
# 2            False                  False              False            False
# 3            False                  False              False            False
# 4            False                  False              False            False
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
#7 Replace missing values or outliers with any mean or interpolated values.


TDC = int(df["total day calls"].mean())
print(TDC)
df["total day calls"].fillna(TDC,inplace=True)

TEC=int(df["total eve calls"].mean())
print(TEC)
df["total eve calls"].fillna(TEC,inplace=True)

TNC=int(df["total night calls"].mean())
print(TNC)
df["total night calls"].fillna(TNC,inplace=True)

TIC=int(df["total intl calls"].mean())
print(TIC)
df["total intl calls"].fillna(TIC,inplace=True)

print("Replaced missing values by Adding Mean Value")
df.isnull().sum()
# Out:
# 100
# 100
# 100
# 4
# Replaced missing values by Adding Mean Value
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
#8 Display the first 10 entries of total evening minutes, total night minutes, total day minutes, total international minutes

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds,columns=["total eve minutes","total night minutes","total day minutes","total intl minutes"])
print(df.head(10))
# Out:
#    total eve minutes  total night minutes  total day minutes  \
# 0              197.4                244.7              265.1
# 1              195.5                254.4              161.6
# 2              121.2                162.6              243.4
# 3               61.9                196.9              299.4
# 4              148.3                186.9              166.7
# 5              220.6                203.9              223.4
# 6              348.5                212.6              218.2
# 7              103.1                211.8              157.0
# 8              351.6                215.8              184.5
# 9              222.0                326.4              258.6
#
#    total intl minutes
# 0                10.0
# 1                13.7
# 2                12.2
# 3                 6.6
# 4                10.1
# 5                 6.3
# 6                 7.5
# 7                 7.1
# 8                 8.7
# 9                11.2

# %%
#8 Display the first 10 entries of total evening minutes, total night minutes, total day minutes, total international minutes

ds=df.loc[:,["total eve minutes","total night minutes","total day minutes","total intl minutes"]]
ds.head(10)
# Out:
#    total eve minutes  total night minutes  total day minutes  \
# 0              197.4                244.7              265.1
# 1              195.5                254.4              161.6
# 2              121.2                162.6              243.4
# 3               61.9                196.9              299.4
# 4              148.3                186.9              166.7
# 5              220.6                203.9              223.4
# 6              348.5                212.6              218.2
# 7              103.1                211.8              157.0
# 8              351.6                215.8              184.5
# 9              222.0                326.4              258.6
#
#    total intl minutes
# 0                10.0
# 1                13.7
# 2                12.2
# 3                 6.6
# 4                10.1
# 5                 6.3
# 6                 7.5
# 7                 7.1
# 8                 8.7
# 9                11.2

# %%
#9 Display the first 10 entries of total total day calls, total eve calls, total day minutes, total intl calls

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds,columns=["total day calls", "total eve calls", "total day minutes", "total intl calls"])
print(df.head(10))
# Out:
#    total day calls  total eve calls  total day minutes  total intl calls
# 0            110.0             99.0              265.1               3.0
# 1            123.0            103.0              161.6               3.0
# 2            114.0            110.0              243.4               5.0
# 3             71.0             88.0              299.4               7.0
# 4            113.0            122.0              166.7               3.0
# 5             98.0            101.0              223.4               6.0
# 6             88.0            108.0              218.2               7.0
# 7             79.0             94.0              157.0               NaN
# 8             97.0             10.0              184.5               4.0
# 9             84.0              NaN              258.6               5.0

# %%
#9 Display the first 10 entries of total total day calls, total eve calls, total day minutes, total intl calls

ds=df.loc[:,["total day calls", "total eve calls", "total day minutes", "total intl calls"]]
ds.head(10)
# Out:
#    total day calls  total eve calls  total day minutes  total intl calls
# 0            110.0             99.0              265.1               3.0
# 1            123.0            103.0              161.6               3.0
# 2            114.0            110.0              243.4               5.0
# 3             71.0             88.0              299.4               7.0
# 4            113.0            122.0              166.7               3.0
# 5             98.0            101.0              223.4               6.0
# 6             88.0            108.0              218.2               7.0
# 7             79.0             94.0              157.0               4.0
# 8             97.0             10.0              184.5               4.0
# 9             84.0            100.0              258.6               5.0

# %%
#10 Display the first 10 entries of number of customer services calls 

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds,columns=["customer service calls"])
print(df.head(10))
# Out:
#    customer service calls
# 0                       1
# 1                       1
# 2                       0
# 3                       2
# 4                       3
# 5                       0
# 6                       3
# 7                       0
# 8                       1
# 9                       0

# %%
#11 Display the first 20 entries of eve calls > 100 and day calls >100

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)

totalcalls=pd.DataFrame(df,columns=["total eve calls","total day calls"])

ds = df.loc[(totalcalls["total eve calls"]>100) & (totalcalls["total day calls"]>100)]
ds.head(20)
# Out:
#    state  account length  area code phone number international plan  \
# 1     OH             107        415     371-7191                 no
# 2     NJ             137        415     358-1921                 no
# 4     OK              75        415     330-6626                yes
# 10    IN              65        415     329-6603                 no
# 17    VT              93        510     386-2923                 no
# 23    SC             111        415     350-2565                 no
# 26    WY              57        408     357-3817                 no
# 29    HI              49        510     410-7789                 no
# 31    NH              75        510     370-3359                 no
# 32    LA             172        408     383-1121                 no
# 33    AZ              12        408     360-1596                 no
# 46    MI              65        415     363-5450                 no
# 48    ID             119        415     398-1294                 no
# ...

# %%
#12 Display a bar chart of number of churns happened with total eve calls > 100

import matplotlib.pyplot as plt
totalcalls=pd.DataFrame(df,columns=["total eve calls","churn"])
ds = totalcalls.loc[totalcalls["total eve calls"]>100]
print(ds)

plt.bar(x=ds["churn"],height=ds["total eve calls"])
plt.title("Churns VS Total eve calls")
plt.ylabel("TOTAL EVE CALLS")
plt.xlabel("CHURNS")
plt.show()
# Out:
#       total eve calls  churn
# 1               103.0  False
# 2               110.0  False
# 4               122.0  False
# 5               101.0  False
# 6               108.0  False
# ...               ...    ...
# 3319            115.0  False
# 3321            110.0  False
# 3322            122.0   True
# 3324            105.0  False
# 3328            126.0  False
#
# [1661 rows x 2 columns]

# %%
#13 Display a bar chart of number of churns happened with total night calls > 100

totalcalls=pd.DataFrame(df,columns=["total night calls","churn"])
ds = totalcalls.loc[totalcalls["total night calls"]>100]
print(ds)

plt.bar(x=ds["churn"],height=ds["total night calls"])
plt.title("Churns VS Total night calls")
plt.ylabel("TOTAL NIGHT CALLS")
plt.xlabel("CHURNS")
plt.show()
# Out:
#       total night calls  churn
# 1                 103.0  False
# 2                 104.0  False
# 4                 121.0  False
# 5                 118.0  False
# 6                 118.0  False
# ...                 ...    ...
# 3321              134.0  False
# 3325              109.0  False
# 3327              128.0  False
# 3329              123.0  False
# 3331              137.0  False
#
# [1654 rows x 2 columns]

# %%
#14 Display a bar chart of number of churns happened with total international calls > 10

import pandas as pd
import matplotlib.pyplot as plt

ds=pd.read_csv("C:\\Users\\Renji\\Downloads\\Telecom_Churn.csv")
df=pd.DataFrame(ds)
totalcalls=pd.DataFrame(df,columns=["total intl calls","churn"])
ds = totalcalls.loc[totalcalls["total intl calls"]>10]
print(ds)

plt.bar(x=ds["churn"],height=ds["total intl calls"])
plt.title("Churns VS Total International calls")
plt.ylabel("TOTAL INTERNATIONAL CALLS")
plt.xlabel("CHURNS")
plt.show()
# Out:
#       total intl calls  churn
# 22                19.0  False
# 41                15.0   True
# 153               11.0  False
# 182               12.0  False
# 185               13.0  False
# ...                ...    ...
# 3128              11.0  False
# 3206              13.0  False
# 3230              14.0  False
# 3291              20.0   True
# 3310              17.0  False
#
# [78 rows x 2 columns]

# %%
#15 Identify the total day calls, total eve calls, total night calls and total international calls, in different areas 

totalcalls=pd.DataFrame(df,columns=["area code","total day calls","total eve calls","total night calls","total intl calls"])
totalcalls.groupby(["area code"]).sum()
# Out:
#            total day calls  total eve calls  total night calls  \
# area code
# 408                83992.0          83302.0            83392.0
# 415               166327.0         167448.0           166940.0
# 510                84082.0          84625.0            84829.0
#
#            total intl calls
# area code
# 408                  3700.0
# 415                  7538.0
# 510                  3666.0

# %%
#16 Identify the total day calls, total eve calls, total night calls and total international calls in different states 

totalcalls=pd.DataFrame(df,columns=["state","total day calls","total eve calls","total night calls","total intl calls"])
totalcalls.groupby(["state"]).sum()
# Out:
#        total day calls  total eve calls  total night calls  total intl calls
# state
# AK              4954.0           5022.0             5062.0             244.0
# AL              7928.0           7877.0             7889.0             376.0
# AR              5618.0           5381.0             5448.0             258.0
# AZ              6407.0           6477.0             6321.0             311.0
# CA              3553.0           3419.0             3373.0             151.0
# CO              6278.0           6479.0             6406.0             271.0
# CT              7284.0           7335.0             7569.0             304.0
# DC              5409.0           5507.0             5274.0             211.0
# DE              6017.0           5939.0             6174.0             262.0
# FL              6363.0           6862.0             6321.0             251.0
# GA              5565.0           5610.0             6247.0             219.0
# ...

# %%
#17 Which area has the max churns

totalcalls=pd.DataFrame(df,columns=["area code","churn"])
totalcalls.groupby(["area code"]).sum()
# Out:
#            churn
# area code
# 408          122
# 415          236
# 510          125

# %%
totalcalls=pd.DataFrame(df,columns=["area code","churn"])
totalcalls.groupby(["area code"]).sum()
max(ds["churn"])
# Out:
# 18

# %%
#18 Which state has the max churns

totalcalls=pd.DataFrame(df,columns=["state","churn"])
totalcalls.groupby(["state"]).sum()
# Out:
#        churn
# state
# AK         3
# AL         8
# AR        11
# AZ         4
# CA         9
# CO         9
# CT        12
# DC         5
# DE         9
# FL         8
# GA         8
# HI         3
# IA         3
# ID         9
# IL         5
# IN         9
# KS        13
# KY         8
# LA         4
# MA        11
# MD        17
# ME        13
# MI        16
# MN        15
# MO         7
# MS        14
# MT        14
# NC        11
# ND         6
# NE         5
# NH         9
# NJ        18
# NM         6
# NV        14
# NY        15
# OH        10
# OK         9
# OR        11
# PA         8
# RI         6
# SC        14
# SD         8
# TN         5
# TX        18
# UT        10
# VA         5
# VT         8
# WA        14
# WI         7
# WV        10
# WY         9

# %%
totalcalls=pd.DataFrame(df,columns=["state","churn"])
totalcalls.groupby(["state"]).sum()
max(ds["churn"])
# Out:
# 18

# %%
#19 Average number of day, evening, and night calls by area code


totalcalls=pd.DataFrame(df,columns=["area code","total day calls", "total eve calls","total night calls"])
totalcalls.groupby(["area code"]).mean()
# Out:
#            total day calls  total eve calls  total night calls
# area code
# 408             100.468900        99.643541          99.632019
# 415             100.560459       101.238210         101.053269
# 510             100.097619       100.744048         101.107271

# %%
#20 Calculate the total number of calls for all users

totalcalls=pd.DataFrame(df,columns=["phone number","total day calls","total eve calls","total night calls","total intl calls"])
totalcalls["total calls"]=totalcalls["total day calls"]+totalcalls["total eve calls"]+totalcalls["total night calls"]+totalcalls["total intl calls"]
totalcalls
# Out:
#      phone number  total day calls  total eve calls  total night calls  \
# 0        382-4657            110.0             99.0               91.0
# 1        371-7191            123.0            103.0              103.0
# 2        358-1921            114.0            110.0              104.0
# 3        375-9999             71.0             88.0               89.0
# 4        330-6626            113.0            122.0              121.0
# ...           ...              ...              ...                ...
# 3328     414-4276             77.0            126.0               83.0
# 3329     370-3271             57.0             55.0              123.0
# 3330     328-8230            109.0             58.0               91.0
# 3331     364-6381            105.0             84.0              137.0
# 3332     400-4344            113.0             82.0               77.0
#
#       total intl calls  total calls
# 0                  3.0        303.0
# 1                  3.0        332.0
# ...
